# %%
import pandas as pd

from inference import load_model

data = pd.DataFrame({
    "sepal_length": [5.1,],
    "sepal_width": [3.5,],
    "petal_length": [1.4,],
    "petal_width": [0.2,],
})

model = load_model("../models/model.joblib")

predictions = model.predict(data)

print(predictions)
# Out:
# [0]
